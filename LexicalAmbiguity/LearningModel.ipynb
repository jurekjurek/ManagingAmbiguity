# %%
'''
In this file, we train a model which we will susequently reason with to explain superposition over ambiguity and different interpretations of ambiguous sentences

We use the dataset dataset.txt, and create VQCs using the Python library lambeq

We then train the VQCs on the data, following the pipeline presented by 
https://www.jair.org/index.php/jair/article/view/14329/26923
and we report the entropy and fidelity values. 
'''

# import all sorts of stuff 
from lambeq.backend.grammar import (Box, Cap, Cup, Diagram, Diagrammable,
                                    Functor, grammar, Id, Spider, Swap,
                                    Ty, Word)
from lambeq.backend.drawing import draw
import matplotlib.pyplot as plt
import matplotlib
from lambeq import AtomicType

# optimising the diagram to make the resulting quanutm circuit less complex
from lambeq import RemoveSwapsRewriter, RemoveCupsRewriter
from lambeq import Rewriter 

# creating the quantum circuit
from lambeq import IQPAnsatz
from pytket.extensions.qiskit import tk_to_qiskit

import numpy as np

# amplitude Encoding
from qiskit import QuantumCircuit

# %%
import numpy as np

BATCH_SIZE = 10

SEED = 2

LEARNING_RATE = 3e-2

# %%
sentenceWithLabel = []

def read_data(filename):
    labels, sentences = [], []
    with open(filename) as f:
        for line in f:
            t = int(line[0])
            labels.append([t, 1-t])
            sentences.append(line[1:].strip())
            sentenceWithLabel.append((line[1:].strip(), [t, 1-t]))
    return sentenceWithLabel

import random 



def train_test_split(data, test_size=0.2):

    random.shuffle(data)
    # Split the data into training and testing sets
    split_index = int(len(data) * (1 - test_size))
    train_data = data#[:split_index]
    return train_data#, test_data

# note that words labelled with '1', receive the label  |0> = [1,0]

data = read_data('dataset.txt')
trainData = train_test_split(data)

print(trainData)

train_labels = []
trainSentences = []
for i in range(len(trainData)):
    sent, lab = trainData[i]
    train_labels.append(lab)
    trainSentences.append(sent)
# Out:
# [('pasta is starving', [0, 1]), ('pancakes are delicious', [1, 0]), ('pancakes are tasty', [1, 0]), ('men are starving', [1, 0]), ('women are hungry', [1, 0]), ('men are hungry', [1, 0]), ('men are delicious', [0, 1]), ('pancakes are starving', [0, 1]), ('women are tasty', [0, 1]), ('pasta is hungry', [0, 1]), ('pasta is tasty', [1, 0]), ('women are delicious', [0, 1]), ('pancakes are hungry', [0, 1]), ('women are starving', [1, 0]), ('men are tasty', [0, 1]), ('pasta is delicious', [1, 0])]

# %%
from lambeq import BobcatParser

parser = BobcatParser(verbose='text')

raw_train_diagrams = parser.sentences2diagrams(trainSentences, suppress_exceptions=True)
# Out:
# Tagging sentences.
# Parsing tagged sentences.
# Turning parse trees to diagrams.

# %%
from lambeq.backend.grammar import Cup, Diagram, Id, Word
from lambeq.backend.drawing import draw

from lambeq import AtomicType

N = AtomicType.NOUN
S = AtomicType.SENTENCE
from lambeq import Rewriter

rewriter = Rewriter()

# %%
# first, boys are hungry -> boys hungry 

from lambeq import Rewriter

rewriter = Rewriter()

raw_train_diagrams_new = [Rewriter(['auxiliary'])(diagram).normal_form() for diagram in raw_train_diagrams]



# normalising 

from lambeq import RemoveCupsRewriter

remove_cups = RemoveCupsRewriter()

train_diagrams = [remove_cups(diagram) for diagram in raw_train_diagrams_new]

# draw - debug
# for diag in train_diagrams:
#     diag.draw()

# %%
# create quantum circuits

from lambeq import AtomicType, IQPAnsatz

# choose IQP ansatz with one qubit each and 3 layers 
ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1},
                   n_layers=3, n_single_qubit_params=3)

train_circuits = [ansatz(diagram) for diagram in raw_train_diagrams_new]
# test_circuits = [ansatz(diagram) for diagram in test_diagrams]

# drawing one quantum circuit, corresponding to the first sentence in the dataset. 
train_circuits[0].draw(figsize= (10,10))

# %%
from lambeq import Dataset

all_circuits = train_circuits# + test_circuits

train_dataset = Dataset(train_circuits,
                        train_labels,
                        batch_size=BATCH_SIZE)

# %%
'''
Same thing, but for Tket model 
'''

EPOCHS = 600


from pytket.extensions.qiskit import AerBackend
from lambeq import TketModel

backend = AerBackend()
backend_config = {
    'backend': backend,
    'compilation': backend.default_compilation_pass(2),
    'shots': 8192
}

modelTK = TketModel.from_diagrams(all_circuits, backend_config=backend_config)

from lambeq import BinaryCrossEntropyLoss

# Using the builtin binary cross-entropy error from lambeq
bceTK = BinaryCrossEntropyLoss()

accTK = lambda y_hat, y: np.sum(np.round(y_hat) == y) / len(y) / 2  # half due to double-counting
eval_metricsTK = {"acc": accTK}

from lambeq import QuantumTrainer, SPSAOptimizer

trainerTK = QuantumTrainer(
    modelTK,
    loss_function=bceTK,
    epochs=EPOCHS,
    optimizer=SPSAOptimizer,
    optim_hyperparams={'a': 0.05, 'c': 0.06, 'A':0.001*EPOCHS},
    evaluate_functions=eval_metricsTK,
    evaluate_on_train=True,
    verbose = 'text',
    log_dir='Logs/logs',
    seed=0
)


trainerTK.fit(train_dataset)#, test_dataset)#, early_stopping_interval=10)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Epoch 1:    train/loss: 1.5543   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 2:    train/loss: 0.9330   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 3:    train/loss: 0.9484   valid/loss: -----   train/acc: 0.4375   valid/acc: -----
# Epoch 4:    train/loss: 1.0239   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 5:    train/loss: 2.8176   valid/loss: -----   train/acc: 0.5625   valid/acc: -----
# Epoch 6:    train/loss: 1.2427   valid/loss: -----   train/acc: 0.4375   valid/acc: -----
# Epoch 7:    train/loss: 1.4317   valid/loss: -----   train/acc: 0.4375   valid/acc: -----
# Epoch 8:    train/loss: 1.0657   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 9:    train/loss: 0.8356   valid/loss: -----   train/acc: 0.4375   valid/acc: -----
# Epoch 10:   train/loss: 0.8642   valid/loss: -----   train/acc: 0.5625   valid/acc: -----
# Epoch 11:   train/loss: 0.8978   valid/loss: -----   train/acc: 0.5625   valid/acc: -----
# Epoch 12:   train/loss: 0.8572   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 13:   train/loss: 0.7554   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 14:   train/loss: 0.4881   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 15:   train/loss: 0.7901   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 16:   train/loss: 0.7551   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 17:   train/loss: 0.5731   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 18:   train/loss: 0.6475   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 19:   train/loss: 0.7626   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 20:   train/loss: 0.3087   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 21:   train/loss: 0.4404   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 22:   train/loss: 0.7434   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 23:   train/loss: 0.8974   valid/loss: -----   train/acc: 0.4375   valid/acc: -----
# Epoch 24:   train/loss: 0.9807   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 25:   train/loss: 0.8067   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 26:   train/loss: 0.5496   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 27:   train/loss: 0.7165   valid/loss: -----   train/acc: 0.5625   valid/acc: -----
# Epoch 28:   train/loss: 0.7137   valid/loss: -----   train/acc: 0.3125   valid/acc: -----
# Epoch 29:   train/loss: 0.8403   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 30:   train/loss: 0.4663   valid/loss: -----   train/acc: 0.5625   valid/acc: -----
# Epoch 31:   train/loss: 0.7544   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 32:   train/loss: 0.9756   valid/loss: -----   train/acc: 0.5625   valid/acc: -----
# Epoch 33:   train/loss: 0.8793   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 34:   train/loss: 0.7368   valid/loss: -----   train/acc: 0.4375   valid/acc: -----
# Epoch 35:   train/loss: 0.6831   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 36:   train/loss: 0.5263   valid/loss: -----   train/acc: 0.4375   valid/acc: -----
# Epoch 37:   train/loss: 0.5238   valid/loss: -----   train/acc: 0.5625   valid/acc: -----
# Epoch 38:   train/loss: 0.8149   valid/loss: -----   train/acc: 0.4375   valid/acc: -----
# Epoch 39:   train/loss: 0.7221   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 40:   train/loss: 0.7902   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 41:   train/loss: 0.6302   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 42:   train/loss: 0.4300   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 43:   train/loss: 0.7282   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 44:   train/loss: 0.6450   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 45:   train/loss: 0.8845   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 46:   train/loss: 0.9132   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 47:   train/loss: 0.8873   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 48:   train/loss: 0.6879   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 49:   train/loss: 0.6782   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 50:   train/loss: 0.5684   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 51:   train/loss: 0.6134   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 52:   train/loss: 0.4803   valid/loss: -----   train/acc: 0.5000   valid/acc: -----
# Epoch 53:   train/loss: 0.5291   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 54:   train/loss: 0.5868   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 55:   train/loss: 0.5178   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 56:   train/loss: 0.5374   valid/loss: -----   train/acc: 0.7188   valid/acc: -----
# Epoch 57:   train/loss: 0.4915   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 58:   train/loss: 0.2700   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 59:   train/loss: 0.4479   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 60:   train/loss: 0.6059   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 61:   train/loss: 0.6484   valid/loss: -----   train/acc: 0.6250   valid/acc: -----
# Epoch 62:   train/loss: 0.4615   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 63:   train/loss: 0.4884   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 64:   train/loss: 0.5741   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 65:   train/loss: 0.5107   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 66:   train/loss: 0.5282   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 67:   train/loss: 0.4954   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 68:   train/loss: 0.3231   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 69:   train/loss: 0.4663   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 70:   train/loss: 0.3951   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 71:   train/loss: 0.4230   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 72:   train/loss: 0.4654   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 73:   train/loss: 0.3705   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 74:   train/loss: 0.3950   valid/loss: -----   train/acc: 0.9062   valid/acc: -----
# Epoch 75:   train/loss: 0.5456   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 76:   train/loss: 0.3385   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 77:   train/loss: 0.5463   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 78:   train/loss: 0.3763   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 79:   train/loss: 0.3156   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 80:   train/loss: 0.3221   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 81:   train/loss: 0.4613   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 82:   train/loss: 0.4256   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 83:   train/loss: 0.5800   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 84:   train/loss: 0.5363   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 85:   train/loss: 0.5519   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 86:   train/loss: 0.3429   valid/loss: -----   train/acc: 0.6875   valid/acc: -----
# Epoch 87:   train/loss: 0.4781   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 88:   train/loss: 0.4265   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 89:   train/loss: 0.2381   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 90:   train/loss: 0.3602   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 91:   train/loss: 0.4249   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 92:   train/loss: 0.4352   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 93:   train/loss: 0.2829   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 94:   train/loss: 0.3565   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 95:   train/loss: 0.2792   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 96:   train/loss: 0.3527   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 97:   train/loss: 0.2596   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 98:   train/loss: 0.3742   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 99:   train/loss: 0.4345   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 100:  train/loss: 0.4296   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 101:  train/loss: 0.3055   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 102:  train/loss: 0.2902   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 103:  train/loss: 0.2193   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 104:  train/loss: 0.3745   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 105:  train/loss: 0.3552   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 106:  train/loss: 0.2824   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 107:  train/loss: 0.2403   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 108:  train/loss: 0.2586   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 109:  train/loss: 0.3123   valid/loss: -----   train/acc: 0.7500   valid/acc: -----
# Epoch 110:  train/loss: 0.3883   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 111:  train/loss: 0.2967   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 112:  train/loss: 0.2953   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 113:  train/loss: 0.3094   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 114:  train/loss: 0.3746   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 115:  train/loss: 0.2445   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 116:  train/loss: 0.2014   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 117:  train/loss: 0.3533   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 118:  train/loss: 0.3567   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 119:  train/loss: 0.2490   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 120:  train/loss: 0.2526   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 121:  train/loss: 0.2569   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 122:  train/loss: 0.1971   valid/loss: -----   train/acc: 0.8125   valid/acc: -----
# Epoch 123:  train/loss: 0.2592   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 124:  train/loss: 0.2630   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 125:  train/loss: 0.2623   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 126:  train/loss: 0.2818   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 127:  train/loss: 0.2174   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 128:  train/loss: 0.2860   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 129:  train/loss: 0.2256   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 130:  train/loss: 0.2636   valid/loss: -----   train/acc: 0.8750   valid/acc: -----
# Epoch 131:  train/loss: 0.2451   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 132:  train/loss: 0.2679   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 133:  train/loss: 0.2893   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 134:  train/loss: 0.3158   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 135:  train/loss: 0.2761   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 136:  train/loss: 0.2893   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 137:  train/loss: 0.2796   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 138:  train/loss: 0.3311   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 139:  train/loss: 0.2383   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 140:  train/loss: 0.2239   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 141:  train/loss: 0.1868   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 142:  train/loss: 0.2219   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 143:  train/loss: 0.2152   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 144:  train/loss: 0.1679   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 145:  train/loss: 0.2336   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 146:  train/loss: 0.1901   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 147:  train/loss: 0.1678   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 148:  train/loss: 0.2918   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 149:  train/loss: 0.1916   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 150:  train/loss: 0.2066   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 151:  train/loss: 0.1793   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 152:  train/loss: 0.2236   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 153:  train/loss: 0.2406   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 154:  train/loss: 0.2399   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 155:  train/loss: 0.1457   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 156:  train/loss: 0.1926   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 157:  train/loss: 0.2423   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 158:  train/loss: 0.1687   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 159:  train/loss: 0.1755   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 160:  train/loss: 0.2626   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 161:  train/loss: 0.1583   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 162:  train/loss: 0.2326   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 163:  train/loss: 0.1854   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 164:  train/loss: 0.1905   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 165:  train/loss: 0.1766   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 166:  train/loss: 0.1093   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 167:  train/loss: 0.2532   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 168:  train/loss: 0.2090   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 169:  train/loss: 0.2022   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 170:  train/loss: 0.1974   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 171:  train/loss: 0.1873   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 172:  train/loss: 0.2487   valid/loss: -----   train/acc: 0.9375   valid/acc: -----
# Epoch 173:  train/loss: 0.1951   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 174:  train/loss: 0.2097   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 175:  train/loss: 0.1647   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 176:  train/loss: 0.1236   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 177:  train/loss: 0.2117   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 178:  train/loss: 0.1874   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 179:  train/loss: 0.1942   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 180:  train/loss: 0.1799   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 181:  train/loss: 0.1808   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 182:  train/loss: 0.1642   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 183:  train/loss: 0.1397   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 184:  train/loss: 0.1516   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 185:  train/loss: 0.1873   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 186:  train/loss: 0.1151   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 187:  train/loss: 0.1676   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 188:  train/loss: 0.1274   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 189:  train/loss: 0.1542   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 190:  train/loss: 0.1861   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 191:  train/loss: 0.1437   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 192:  train/loss: 0.1909   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 193:  train/loss: 0.1642   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 194:  train/loss: 0.1389   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 195:  train/loss: 0.1216   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 196:  train/loss: 0.1199   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 197:  train/loss: 0.1638   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 198:  train/loss: 0.1484   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 199:  train/loss: 0.1324   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 200:  train/loss: 0.0932   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 201:  train/loss: 0.1543   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 202:  train/loss: 0.1622   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 203:  train/loss: 0.1658   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 204:  train/loss: 0.1557   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 205:  train/loss: 0.1504   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 206:  train/loss: 0.0892   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 207:  train/loss: 0.0894   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 208:  train/loss: 0.1297   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 209:  train/loss: 0.1082   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 210:  train/loss: 0.1450   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 211:  train/loss: 0.1804   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 212:  train/loss: 0.1898   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 213:  train/loss: 0.1538   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 214:  train/loss: 0.1593   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 215:  train/loss: 0.1476   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 216:  train/loss: 0.1580   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 217:  train/loss: 0.1585   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 218:  train/loss: 0.0663   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 219:  train/loss: 0.1202   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 220:  train/loss: 0.1347   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 221:  train/loss: 0.1749   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 222:  train/loss: 0.1048   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 223:  train/loss: 0.1635   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 224:  train/loss: 0.0919   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 225:  train/loss: 0.1697   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 226:  train/loss: 0.1447   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 227:  train/loss: 0.1067   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 228:  train/loss: 0.1082   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 229:  train/loss: 0.1141   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 230:  train/loss: 0.1832   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 231:  train/loss: 0.1754   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 232:  train/loss: 0.1192   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 233:  train/loss: 0.1287   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 234:  train/loss: 0.1161   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 235:  train/loss: 0.1269   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 236:  train/loss: 0.1705   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 237:  train/loss: 0.1755   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 238:  train/loss: 0.0848   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 239:  train/loss: 0.1488   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 240:  train/loss: 0.1547   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 241:  train/loss: 0.1136   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 242:  train/loss: 0.1191   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 243:  train/loss: 0.0632   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 244:  train/loss: 0.1621   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 245:  train/loss: 0.1601   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 246:  train/loss: 0.1794   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 247:  train/loss: 0.1395   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 248:  train/loss: 0.1326   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 249:  train/loss: 0.1047   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 250:  train/loss: 0.1104   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 251:  train/loss: 0.1243   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 252:  train/loss: 0.1246   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 253:  train/loss: 0.1288   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 254:  train/loss: 0.1409   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 255:  train/loss: 0.1313   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 256:  train/loss: 0.1169   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 257:  train/loss: 0.1419   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 258:  train/loss: 0.1127   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 259:  train/loss: 0.1057   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 260:  train/loss: 0.1103   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 261:  train/loss: 0.1292   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 262:  train/loss: 0.1253   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 263:  train/loss: 0.1540   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 264:  train/loss: 0.1143   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 265:  train/loss: 0.1669   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 266:  train/loss: 0.1093   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 267:  train/loss: 0.1186   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 268:  train/loss: 0.1172   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 269:  train/loss: 0.1522   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 270:  train/loss: 0.1359   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 271:  train/loss: 0.1025   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 272:  train/loss: 0.0798   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 273:  train/loss: 0.1305   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 274:  train/loss: 0.0860   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 275:  train/loss: 0.1162   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 276:  train/loss: 0.1115   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 277:  train/loss: 0.1649   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 278:  train/loss: 0.1491   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 279:  train/loss: 0.1662   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 280:  train/loss: 0.1323   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 281:  train/loss: 0.1177   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 282:  train/loss: 0.1146   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 283:  train/loss: 0.1098   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 284:  train/loss: 0.1141   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 285:  train/loss: 0.1153   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 286:  train/loss: 0.1278   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 287:  train/loss: 0.0784   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 288:  train/loss: 0.1363   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 289:  train/loss: 0.1671   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 290:  train/loss: 0.1454   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 291:  train/loss: 0.1174   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 292:  train/loss: 0.1169   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 293:  train/loss: 0.0980   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 294:  train/loss: 0.0898   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 295:  train/loss: 0.1731   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 296:  train/loss: 0.1469   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 297:  train/loss: 0.1199   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 298:  train/loss: 0.1398   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 299:  train/loss: 0.1106   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 300:  train/loss: 0.1426   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 301:  train/loss: 0.1063   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 302:  train/loss: 0.1333   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 303:  train/loss: 0.0999   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 304:  train/loss: 0.0955   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 305:  train/loss: 0.1415   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 306:  train/loss: 0.1728   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 307:  train/loss: 0.1155   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 308:  train/loss: 0.1109   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 309:  train/loss: 0.0775   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 310:  train/loss: 0.1126   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 311:  train/loss: 0.1219   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 312:  train/loss: 0.0990   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 313:  train/loss: 0.1093   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 314:  train/loss: 0.1012   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 315:  train/loss: 0.1511   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 316:  train/loss: 0.1415   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 317:  train/loss: 0.1538   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 318:  train/loss: 0.0957   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 319:  train/loss: 0.1411   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 320:  train/loss: 0.0928   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 321:  train/loss: 0.0910   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 322:  train/loss: 0.0953   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 323:  train/loss: 0.1601   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 324:  train/loss: 0.1040   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 325:  train/loss: 0.1342   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 326:  train/loss: 0.1525   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 327:  train/loss: 0.0876   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 328:  train/loss: 0.1311   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 329:  train/loss: 0.0978   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 330:  train/loss: 0.0983   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 331:  train/loss: 0.1453   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 332:  train/loss: 0.1394   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 333:  train/loss: 0.1380   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 334:  train/loss: 0.1053   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 335:  train/loss: 0.0889   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 336:  train/loss: 0.0874   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 337:  train/loss: 0.0944   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 338:  train/loss: 0.0927   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 339:  train/loss: 0.1169   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 340:  train/loss: 0.1067   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 341:  train/loss: 0.1112   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 342:  train/loss: 0.1293   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 343:  train/loss: 0.0869   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 344:  train/loss: 0.0709   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 345:  train/loss: 0.0995   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 346:  train/loss: 0.1219   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 347:  train/loss: 0.1744   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 348:  train/loss: 0.1280   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 349:  train/loss: 0.1259   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 350:  train/loss: 0.0838   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 351:  train/loss: 0.0832   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 352:  train/loss: 0.1698   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 353:  train/loss: 0.0977   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 354:  train/loss: 0.1364   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 355:  train/loss: 0.1029   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 356:  train/loss: 0.1127   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 357:  train/loss: 0.0933   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 358:  train/loss: 0.0806   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 359:  train/loss: 0.0952   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 360:  train/loss: 0.0896   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 361:  train/loss: 0.0733   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 362:  train/loss: 0.1599   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 363:  train/loss: 0.1172   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 364:  train/loss: 0.1041   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 365:  train/loss: 0.1081   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 366:  train/loss: 0.0698   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 367:  train/loss: 0.0805   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 368:  train/loss: 0.1264   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 369:  train/loss: 0.0872   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 370:  train/loss: 0.1107   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 371:  train/loss: 0.0897   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 372:  train/loss: 0.0529   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 373:  train/loss: 0.1126   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 374:  train/loss: 0.0909   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 375:  train/loss: 0.1007   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 376:  train/loss: 0.0880   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 377:  train/loss: 0.0870   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 378:  train/loss: 0.1288   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 379:  train/loss: 0.1079   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 380:  train/loss: 0.0760   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 381:  train/loss: 0.1099   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 382:  train/loss: 0.1039   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 383:  train/loss: 0.0656   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 384:  train/loss: 0.1043   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 385:  train/loss: 0.0952   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 386:  train/loss: 0.1408   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 387:  train/loss: 0.1458   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 388:  train/loss: 0.1169   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 389:  train/loss: 0.1134   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 390:  train/loss: 0.0902   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 391:  train/loss: 0.0811   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 392:  train/loss: 0.0851   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 393:  train/loss: 0.0850   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 394:  train/loss: 0.1335   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 395:  train/loss: 0.1046   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 396:  train/loss: 0.0934   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 397:  train/loss: 0.1259   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 398:  train/loss: 0.1264   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 399:  train/loss: 0.0666   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 400:  train/loss: 0.0992   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 401:  train/loss: 0.0977   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 402:  train/loss: 0.0911   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 403:  train/loss: 0.1137   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 404:  train/loss: 0.0923   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 405:  train/loss: 0.1217   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 406:  train/loss: 0.0952   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 407:  train/loss: 0.1053   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 408:  train/loss: 0.0833   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 409:  train/loss: 0.1375   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 410:  train/loss: 0.1175   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 411:  train/loss: 0.1216   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 412:  train/loss: 0.0961   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 413:  train/loss: 0.0405   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 414:  train/loss: 0.1615   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 415:  train/loss: 0.0836   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 416:  train/loss: 0.0677   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 417:  train/loss: 0.0781   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 418:  train/loss: 0.1124   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 419:  train/loss: 0.0916   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 420:  train/loss: 0.1105   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 421:  train/loss: 0.1160   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 422:  train/loss: 0.0971   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 423:  train/loss: 0.0981   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 424:  train/loss: 0.0741   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 425:  train/loss: 0.1248   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 426:  train/loss: 0.0779   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 427:  train/loss: 0.1240   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 428:  train/loss: 0.1132   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 429:  train/loss: 0.1058   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 430:  train/loss: 0.0816   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 431:  train/loss: 0.0542   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 432:  train/loss: 0.0775   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 433:  train/loss: 0.0743   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 434:  train/loss: 0.1113   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 435:  train/loss: 0.0537   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 436:  train/loss: 0.0810   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 437:  train/loss: 0.0620   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 438:  train/loss: 0.1348   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 439:  train/loss: 0.0934   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 440:  train/loss: 0.1074   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 441:  train/loss: 0.0815   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 442:  train/loss: 0.0953   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 443:  train/loss: 0.1340   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 444:  train/loss: 0.1104   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 445:  train/loss: 0.0932   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 446:  train/loss: 0.0615   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 447:  train/loss: 0.1144   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 448:  train/loss: 0.0947   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 449:  train/loss: 0.1720   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 450:  train/loss: 0.0775   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 451:  train/loss: 0.0859   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 452:  train/loss: 0.0730   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 453:  train/loss: 0.0969   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 454:  train/loss: 0.0539   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 455:  train/loss: 0.0647   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 456:  train/loss: 0.0939   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 457:  train/loss: 0.0820   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 458:  train/loss: 0.0549   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 459:  train/loss: 0.0617   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 460:  train/loss: 0.0846   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 461:  train/loss: 0.0623   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 462:  train/loss: 0.1143   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 463:  train/loss: 0.1186   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 464:  train/loss: 0.0944   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 465:  train/loss: 0.0778   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 466:  train/loss: 0.1100   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 467:  train/loss: 0.1170   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 468:  train/loss: 0.0910   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 469:  train/loss: 0.1140   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 470:  train/loss: 0.0925   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 471:  train/loss: 0.0990   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 472:  train/loss: 0.1209   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 473:  train/loss: 0.0762   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 474:  train/loss: 0.1121   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 475:  train/loss: 0.1038   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 476:  train/loss: 0.0930   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 477:  train/loss: 0.0834   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 478:  train/loss: 0.1568   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 479:  train/loss: 0.0723   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 480:  train/loss: 0.0895   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 481:  train/loss: 0.0658   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 482:  train/loss: 0.0945   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 483:  train/loss: 0.1436   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 484:  train/loss: 0.1317   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 485:  train/loss: 0.0795   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 486:  train/loss: 0.0785   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 487:  train/loss: 0.0618   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 488:  train/loss: 0.0664   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 489:  train/loss: 0.1014   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 490:  train/loss: 0.0766   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 491:  train/loss: 0.1058   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 492:  train/loss: 0.0752   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 493:  train/loss: 0.0978   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 494:  train/loss: 0.1028   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 495:  train/loss: 0.0793   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 496:  train/loss: 0.1030   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 497:  train/loss: 0.0615   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 498:  train/loss: 0.1091   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 499:  train/loss: 0.0769   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 500:  train/loss: 0.0805   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 501:  train/loss: 0.1025   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 502:  train/loss: 0.0823   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 503:  train/loss: 0.0741   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 504:  train/loss: 0.0702   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 505:  train/loss: 0.0720   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 506:  train/loss: 0.0912   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 507:  train/loss: 0.1024   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 508:  train/loss: 0.1083   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 509:  train/loss: 0.0721   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 510:  train/loss: 0.0943   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 511:  train/loss: 0.0683   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 512:  train/loss: 0.1201   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 513:  train/loss: 0.0782   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 514:  train/loss: 0.0873   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 515:  train/loss: 0.0606   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 516:  train/loss: 0.0761   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 517:  train/loss: 0.0948   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 518:  train/loss: 0.1459   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 519:  train/loss: 0.1579   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 520:  train/loss: 0.0588   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 521:  train/loss: 0.0906   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 522:  train/loss: 0.0709   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 523:  train/loss: 0.0776   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 524:  train/loss: 0.1016   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 525:  train/loss: 0.0800   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 526:  train/loss: 0.0404   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 527:  train/loss: 0.0908   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 528:  train/loss: 0.0680   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 529:  train/loss: 0.0765   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 530:  train/loss: 0.0569   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 531:  train/loss: 0.0914   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 532:  train/loss: 0.0878   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 533:  train/loss: 0.1044   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 534:  train/loss: 0.0767   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 535:  train/loss: 0.0983   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 536:  train/loss: 0.0811   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 537:  train/loss: 0.0809   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 538:  train/loss: 0.0644   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 539:  train/loss: 0.0904   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 540:  train/loss: 0.1037   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 541:  train/loss: 0.0828   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 542:  train/loss: 0.0664   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 543:  train/loss: 0.0860   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 544:  train/loss: 0.0963   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 545:  train/loss: 0.1159   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 546:  train/loss: 0.1008   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 547:  train/loss: 0.1041   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 548:  train/loss: 0.1052   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 549:  train/loss: 0.0944   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 550:  train/loss: 0.0875   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 551:  train/loss: 0.0794   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 552:  train/loss: 0.1248   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 553:  train/loss: 0.1051   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 554:  train/loss: 0.0924   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 555:  train/loss: 0.0984   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 556:  train/loss: 0.0541   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 557:  train/loss: 0.0821   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 558:  train/loss: 0.0841   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 559:  train/loss: 0.1019   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 560:  train/loss: 0.0682   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 561:  train/loss: 0.1309   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 562:  train/loss: 0.0763   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 563:  train/loss: 0.0931   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 564:  train/loss: 0.1139   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 565:  train/loss: 0.0869   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 566:  train/loss: 0.0600   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 567:  train/loss: 0.1219   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 568:  train/loss: 0.0751   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 569:  train/loss: 0.0887   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 570:  train/loss: 0.1384   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 571:  train/loss: 0.0704   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 572:  train/loss: 0.1112   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 573:  train/loss: 0.0735   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 574:  train/loss: 0.0438   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 575:  train/loss: 0.0900   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 576:  train/loss: 0.0686   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 577:  train/loss: 0.0836   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 578:  train/loss: 0.1241   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 579:  train/loss: 0.1164   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 580:  train/loss: 0.0800   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 581:  train/loss: 0.0835   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 582:  train/loss: 0.0857   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 583:  train/loss: 0.0585   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 584:  train/loss: 0.0945   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 585:  train/loss: 0.0913   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 586:  train/loss: 0.0529   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 587:  train/loss: 0.1105   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 588:  train/loss: 0.0805   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 589:  train/loss: 0.0648   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 590:  train/loss: 0.0831   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 591:  train/loss: 0.0902   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 592:  train/loss: 0.0721   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 593:  train/loss: 0.1179   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 594:  train/loss: 0.0773   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 595:  train/loss: 0.1146   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 596:  train/loss: 0.0911   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 597:  train/loss: 0.0783   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 598:  train/loss: 0.0772   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 599:  train/loss: 0.0763   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
# Epoch 600:  train/loss: 0.0706   valid/loss: -----   train/acc: 1.0000   valid/acc: -----
#
# Training completed!

# %%
import matplotlib.pyplot as plt

trainer = trainerTK
model = modelTK
acc = accTK
fig, ((ax_tl, ax_tr), (ax_bl, ax_br)) = plt.subplots(2, 2,
                                                     sharex=True,
                                                     sharey='row',
                                                     figsize=(10, 6))
ax_tl.set_title('Training set')
ax_tr.set_title('Development set')
ax_bl.set_xlabel('Iterations')
ax_br.set_xlabel('Iterations')
ax_bl.set_ylabel('Accuracy')
ax_tl.set_ylabel('Loss')

colours = iter(plt.rcParams['axes.prop_cycle'].by_key()['color'])
range_ = np.arange(1, trainer.epochs+1)
ax_tl.plot(range_, trainer.train_epoch_costs, color=next(colours))
ax_bl.plot(range_, trainer.train_eval_results['acc'], color=next(colours))
val_acc = accTK(modelTK(train_circuits), train_labels)
print('Validation accuracy:', val_acc.item())

test_loss = BinaryCrossEntropyLoss()
# Out:
# Validation accuracy: 1.0

# %%
from matplotlib import pyplot as plt

fig, ax1 = plt.subplots(figsize=(13, 8))

# ax1.plot(range_, trainer.train_epoch_costs, '-k', markersize=4, label='cost')
ax1.plot(range_[:int(len(range_) * 0.833333)], trainer.train_epoch_costs[:int(len(range_) * 0.833333)], '-g', markersize=4, label='train loss')
# ax1.plot(range_, trainer.train_eval_results['acc'], '-b', markersize=4, label='train accuracy')
ax1.set_ylabel(r"Loss", fontsize='x-large')
ax1.set_xlabel(r"Epochs", fontsize='x-large')
# ax1.legend(loc='upper center', fontsize='x-large')

ax2 = ax1.twinx()
ax2.plot(range_[:int(len(range_) * 0.833333)], trainer.train_eval_results['acc'][:int(len(range_) * 0.833333)], '-b', markersize=4, label='train accuracy')
ax2.set_ylabel(r"Accuracy", fontsize='x-large')
# ax2.plot(range_, trainer.train_epoch_costs, '-g', markersize=4, label='train error')
# ax2.plot(range(len(trainer.val_costs)), trainer.val_costs, '-b', markersize=4, label='dev error')
# ax2.plot(range(len(trainer.train_costs)), trainer.train_costs, '-r', markersize=4, label='test error')
# ax1.legend(loc='center', fontsize='x-large')
# ax2.legend(loc='upper right', fontsize='x-large')

fig.legend(loc='center', fontsize='x-large')

plt.title('Tket model, ambiguity over syntax', fontsize='x-large')
plt.savefig('MC_task_ECS_Results.png', dpi=300, facecolor='white')  
plt.show()

# %%
smbls = modelTK.symbols
# And the weights are their respective values 
weights = modelTK.weights

# print(smbls)
# print(weights)

# %%
import re 

def extract_word_and_number(strings):
    new_strings = []
    for s in strings:
        match = re.match(r'^([a-zA-Z]+).*?(\d+)$', str(s))
        # print(str(s))
        if match:
            new_strings.append(f"{match.group(1)}{match.group(2)}")
    return new_strings

newSmbls = extract_word_and_number(smbls)
# print(weights)

parameterDict = {}

for i in range(len(newSmbls)):
    parameterDict[newSmbls[i]] = weights[i]

print(parameterDict)
# Out:
# {'delicious0': 0.6174608303256235, 'delicious1': 1.43527514218808, 'delicious2': 1.7132784383533273, 'hungry0': 0.017825612369642918, 'hungry1': -0.1965701224908135, 'hungry2': 1.5321560912944943, 'men0': 0.6403163574377728, 'men1': 1.6963546327073364, 'men2': 1.4301936098494599, 'pancakes0': 0.7048976051587932, 'pancakes1': 1.1820794552859963, 'pancakes2': 0.7388301660003596, 'pasta0': -0.2887909310172229, 'pasta1': 1.3224869192766133, 'pasta2': 0.07002073596481112, 'starving0': 0.8366758453366762, 'starving1': -0.47709970794740497, 'starving2': 0.500495140087928, 'tasty0': 0.4098377742826135, 'tasty1': 0.9922755470171698, 'tasty2': 0.9315192432096867, 'women0': 1.1875460474507424, 'women1': 1.1429546139115678, 'women2': 0.7268394452553315}

# %%
from pytket.extensions.qiskit import tk_to_qiskit
from qiskit.circuit import ParameterVector, Parameter

# we explicitly construct the circuit using Qiskit

def DefaultCircuits(nounOne, adjective):
    ''''''

    qc = QuantumCircuit(3)
    

    thetaSubj1 = Parameter(str(nounOne) + '2')
    thetaSubj2 = Parameter(str(nounOne) + '1')
    thetaSubj3 = Parameter(str(nounOne) + '0')

    thetaAdj1  = Parameter(str(adjective) + '0')
    thetaAdj2  = Parameter(str(adjective) + '1')
    thetaAdj3  = Parameter(str(adjective) + '2')

    qc.rx(thetaSubj1, 0)
    qc.rz(thetaSubj2, 0)
    qc.rx(thetaSubj3, 0)

    # layer one 
    qc.h(1)
    qc.h(2)

    qc.crz(thetaAdj1, 1,2)

    qc.h(1)
    qc.h(2)

    # layer two

    qc.crz(thetaAdj2, 1,2)

    qc.h(1)
    qc.h(2)

    # layer three

    qc.crz(thetaAdj3, 1,2)

    qc.h(1)
    qc.h(2)

    qc.cx(0,1)

    qc.h(0)

    params = qc.parameters
    # set the parameters of the remaining words based on the models weights 
    for i in range(len(params)):
        print(params[i])
        if str(params[i]) in parameterDict:

            # print('DEBUGDEBUGDEBUGDEBUG,  if we put in parameter ', parameterDict[str(params[i])], 'for the label: ', str(params[i]))
            qc = qc.assign_parameters({params[i]: 2*np.pi*(parameterDict[str(params[i])])})
            print(parameterDict[str(params[i])])

    return qc


circuit = DefaultCircuits('women', 'hungry')
circuit2 = DefaultCircuits('men', 'hungry')
circuit3 = DefaultCircuits('women', 'starving')
circuit4 = DefaultCircuits('men', 'starving')
circuit5= DefaultCircuits('pancakes', 'tasty')
circuit6 = DefaultCircuits('pasta', 'tasty')
circuit7= DefaultCircuits('pancakes', 'delicious')
circuit8 = DefaultCircuits('pasta', 'delicious')
print(circuit)

def GetDMFromCircuit(circuit):


    import qiskit.quantum_info as qi 

    # rho = qi.DensityMatrix(circuit)
    rho = qi.Statevector(circuit)
    tempRho = rho.measure([0,1])

    while '1' in tempRho[0]:
        tempRho = rho.measure([0, 1])

    print(tempRho[0])

    rhoNew = tempRho[1]
    rhoFinal = qi.partial_trace(rhoNew, [0,1])

    return rhoFinal

import qiskit.quantum_info as qi 

sigma = qi.DensityMatrix([[0,0] ,[0,1]])

rhoFinal1 = qi.state_fidelity(GetDMFromCircuit(circuit), sigma)
rhoFinal2 = qi.state_fidelity(GetDMFromCircuit(circuit2), sigma)
rhoFinal3 = qi.state_fidelity(GetDMFromCircuit(circuit3), sigma)
rhoFinal4 = qi.state_fidelity(GetDMFromCircuit(circuit4), sigma)
rhoFinal5= qi.state_fidelity(GetDMFromCircuit(circuit5), sigma)
rhoFinal6 = qi.state_fidelity(GetDMFromCircuit(circuit6), sigma)
rhoFinal7= qi.state_fidelity(GetDMFromCircuit(circuit7), sigma)
rhoFinal8 = qi.state_fidelity(GetDMFromCircuit(circuit8), sigma)

result = rhoFinal8 + rhoFinal1 + rhoFinal2 + rhoFinal3 + rhoFinal4 + rhoFinal5 + rhoFinal6 + rhoFinal7
result = result / 8

print('avg fidelity: ', result)
# Out:
# hungry0
# 0.017825612369642918
# hungry1
# -0.1965701224908135
# hungry2
# 1.5321560912944943
# women0
# 1.1875460474507424
# women1
# 1.1429546139115678
# women2
# 0.7268394452553315
# hungry0
# 0.017825612369642918
# hungry1
# -0.1965701224908135
# hungry2
# 1.5321560912944943
# men0
# 0.6403163574377728
# men1
# 1.6963546327073364
# men2
# 1.4301936098494599
# starving0
# 0.8366758453366762
# starving1
# -0.47709970794740497
# starving2
# 0.500495140087928
# women0
# 1.1875460474507424
# women1
# 1.1429546139115678
# women2
# 0.7268394452553315
# men0
# 0.6403163574377728
# men1
# 1.6963546327073364
# men2
# 1.4301936098494599
# starving0
# 0.8366758453366762
# starving1
# -0.47709970794740497
# starving2
# 0.500495140087928
# pancakes0
# 0.7048976051587932
# pancakes1
# 1.1820794552859963
# pancakes2
# 0.7388301660003596
# tasty0
# 0.4098377742826135
# tasty1
# 0.9922755470171698
# tasty2
# 0.9315192432096867
# pasta0
# -0.2887909310172229
# pasta1
# 1.3224869192766133
# pasta2
# 0.07002073596481112
# tasty0
# 0.4098377742826135
# tasty1
# 0.9922755470171698
# tasty2
# 0.9315192432096867
# delicious0
# 0.6174608303256235
# delicious1
# 1.43527514218808
# delicious2
# 1.7132784383533273
# pancakes0
# 0.7048976051587932
# pancakes1
# 1.1820794552859963
# pancakes2
# 0.7388301660003596
# delicious0
# 0.6174608303256235
# delicious1
# 1.43527514218808
# delicious2
# 1.7132784383533273
# pasta0
# -0.2887909310172229
# pasta1
# 1.3224869192766133
# pasta2
# 0.07002073596481112
#      ┌────────────┐┌────────────┐┌────────────┐                    »
# q_0: ┤ Rx(4.5669) ├┤ Rz(7.1814) ├┤ Rx(7.4616) ├────────────────────»
#      └───┬───┬────┘└────────────┘└───┬───┬────┘               ┌───┐»
# q_1: ────┤ H ├───────────■───────────┤ H ├────────────■───────┤ H ├»
#          ├───┤     ┌─────┴─────┐     ├───┤     ┌──────┴──────┐├───┤»
# q_2: ────┤ H ├─────┤ Rz(0.112) ├─────┤ H ├─────┤ Rz(-1.2351) ├┤ H ├»
#          └───┘     └───────────┘     └───┘     └─────────────┘└───┘»
# «                             ┌───┐
# «q_0: ─────────────────────■──┤ H ├
# «                   ┌───┐┌─┴─┐└───┘
# «q_1: ──────■───────┤ H ├┤ X ├─────
# «     ┌─────┴──────┐├───┤└───┘
# «q_2: ┤ Rz(9.6268) ├┤ H ├──────────
# «     └────────────┘└───┘
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# 00
# avg fidelity:  0.4979509529079151

# %%
from qiskit.circuit import ParameterVector, Parameter

def CreateCircuit(nounOne, nounTwo, adjective, prob1):
    qc = QuantumCircuit(5)

    thetaSubj1 = Parameter(str(nounOne) + '2')
    thetaSubj2 = Parameter(str(nounOne) + '1')
    thetaSubj3 = Parameter(str(nounOne) + '0')

    thetaObj1 = Parameter(str(nounTwo) + '2')
    thetaObj2 = Parameter(str(nounTwo) + '1')
    thetaObj3 = Parameter(str(nounTwo) + '0')

    thetaAdj1  = Parameter(str(adjective) + '0')
    thetaAdj2  = Parameter(str(adjective) + '1')
    thetaAdj3  = Parameter(str(adjective) + '2')

    qc.rx(thetaSubj1, 1)
    qc.rz(thetaSubj2, 1)
    qc.rx(thetaSubj3, 1)

    qc.rx(thetaObj1, 2)
    qc.rz(thetaObj2, 2)
    qc.rx(thetaObj3, 2)


    # if not prob1 == 0.5:
    # alpha = prob1 / ( (prob1**2 + (1- prob1)**2) )
    # # else: 
    # #     alpha = 0.5

    # # alpha = np.sqrt(prob1)

    # # print('alpha is:', alpha)

    vector = [prob1, 1-prob1]
    initialState = vector / np.linalg.norm(vector)

    # vector = [prob1, 1-prob1]

    # print(initialState)

    # qc.initialize(initialState, 0, normalize=False)



    qc.h(0)
    qc.h(3)
    qc.h(4)
    qc.crz(thetaAdj1, 3, 4)
    qc.h(3)
    qc.h(4)

    # layer two

    qc.crz(thetaAdj2,3, 4)

    qc.h(3)
    qc.h(4)

    # layer three

    qc.crz(thetaAdj3,3, 4)

    qc.h(3)
    qc.h(4)

    qc.ccx(0, 2, 3)
    qc.x(0)
    qc.ccx(0, 1, 3)

    qc.h(1)
    qc.h(2)

    # qc.measure(1,0)
    # qc.measure(2,0)
    # qc.measure(3,0)


    params = qc.parameters
    # set the parameters of the remaining words based on the models weights 
    for i in range(len(params)):
        if str(params[i]) in parameterDict:

            # print('DEBUGDEBUGDEBUGDEBUG,  if we put in parameter ', parameterDict[str(params[i])], 'for the label: ', str(params[i]))
            qc = qc.assign_parameters({params[i]: 2* np.pi*(parameterDict[str(params[i])])})

    return qc

import qiskit.quantum_info as qi 
adjList = ['hungry', 'starving', 'delicious', 'tasty']
subjectList = ['men', 'women', 'pancakes', 'pasta']

def GetEntropyAndFidelity(word1, word2, word3):
    circuit = CreateCircuit(word1, word2, word3, 0)

    # print(circuit)

    rho = qi.DensityMatrix(circuit)
    tempRho = rho.measure([1,2,3])

    while '1' in tempRho[0]:
        tempRho = rho.measure([1,2,3])

    rho = tempRho[1]
    rho = qi.partial_trace(rho, [0,1,2,3])

    sigma = qi.DensityMatrix([[1,0] ,[0,0]])

    return qi.state_fidelity(sigma, rho), qi.entropy(rho)

listOfEntropy = []
listOfFidelity = []

listOfEntropy.append(GetEntropyAndFidelity('men', 'pancakes', 'hungry')[1])
listOfFidelity.append(GetEntropyAndFidelity('men', 'pancakes', 'hungry')[0])

listOfEntropy.append(GetEntropyAndFidelity('men', 'pancakes', 'starving')[1])
listOfFidelity.append(GetEntropyAndFidelity('men', 'pancakes', 'starving')[0])

listOfEntropy.append(GetEntropyAndFidelity('men', 'pasta', 'hungry')[1])
listOfFidelity.append(GetEntropyAndFidelity('men', 'pasta', 'hungry')[0])

listOfEntropy.append(GetEntropyAndFidelity('men', 'pasta', 'starving')[1])
listOfFidelity.append(GetEntropyAndFidelity('men', 'pasta', 'starving')[0])

listOfEntropy.append(GetEntropyAndFidelity('men', 'pancakes', 'delicious')[1])
listOfFidelity.append(GetEntropyAndFidelity('men', 'pancakes', 'delicious')[0])

listOfEntropy.append(GetEntropyAndFidelity('men', 'pancakes', 'tasty')[1])
listOfFidelity.append(GetEntropyAndFidelity('men', 'pancakes', 'tasty')[0])

listOfEntropy.append(GetEntropyAndFidelity('men', 'pasta', 'delicious')[1])
listOfFidelity.append(GetEntropyAndFidelity('men', 'pasta', 'delicious')[0])

listOfEntropy.append(GetEntropyAndFidelity('men', 'pasta', 'tasty')[1])
listOfFidelity.append(GetEntropyAndFidelity('men', 'pasta', 'tasty')[0])

listOfEntropy.append(GetEntropyAndFidelity('women', 'pancakes', 'hungry')[1])
listOfFidelity.append(GetEntropyAndFidelity('women', 'pancakes', 'hungry')[0])

listOfEntropy.append(GetEntropyAndFidelity('women', 'pancakes', 'starving')[1])
listOfFidelity.append(GetEntropyAndFidelity('women', 'pancakes', 'starving')[0])

listOfEntropy.append(GetEntropyAndFidelity('women', 'pasta', 'hungry')[1])
listOfFidelity.append(GetEntropyAndFidelity('women', 'pasta', 'hungry')[0])

listOfEntropy.append(GetEntropyAndFidelity('women', 'pasta', 'starving')[1])
listOfFidelity.append(GetEntropyAndFidelity('women', 'pasta', 'starving')[0])

listOfEntropy.append(GetEntropyAndFidelity('women', 'pancakes', 'delicious')[1])
listOfFidelity.append(GetEntropyAndFidelity('women', 'pancakes', 'delicious')[0])

listOfEntropy.append(GetEntropyAndFidelity('women', 'pancakes', 'tasty')[1])
listOfFidelity.append(GetEntropyAndFidelity('women', 'pancakes', 'tasty')[0])

listOfEntropy.append(GetEntropyAndFidelity('women', 'pasta', 'delicious')[1])
listOfFidelity.append(GetEntropyAndFidelity('women', 'pasta', 'delicious')[0])

listOfEntropy.append(GetEntropyAndFidelity('women', 'pasta', 'tasty')[1])
listOfFidelity.append(GetEntropyAndFidelity('women', 'pasta', 'tasty')[0])


print('average entropy: ', sum(listOfEntropy)/len(listOfEntropy))
print('average fidelity: ', sum(listOfFidelity) / len(listOfFidelity))
# Out:
# average entropy:  0.4462060275321235
# average fidelity:  0.521088344445616
